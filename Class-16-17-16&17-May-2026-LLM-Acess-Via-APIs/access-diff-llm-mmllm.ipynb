# %%
print("all ok")

# %%
input   output
Text -> Text
Text -> Image
Image -> Text
Image -> Image(not required)
Text-> Audio
Audio -> Text
Audio -> Audio(not required)
text -> video
video -> text

# %%
# from gtts import gTTS
# text = "Hello students, today we are learning about multimodal AI, one of the most exciting areas in artificial intelligence, where models can understand and generate multiple types of data such as text, images, audio, and video, enabling powerful applications like image captioning, speech recognition, text-to-image generation, AI voice assistants, visual question answering, and intelligent agentic systems that can interact with the world in a much more human-like way."
# tts = gTTS(text=text, lang="en")
# tts.save("audio.mp3")

# %% [markdown]
# ### text to text model
#
# #### 95% times we are going to use text to text only
#
# ##### so this is imp

# %% [markdown]
# This OpenAI Model is PAID
# Anthropic Models are also PAID
#
# if these are the PAID so everyone can not use it
#
# so you want some free options
#
# so lets me tell me some free options
#
# reading the model from the openai or anthropic server using openai or claude key
#
# our owm server
# how to config the model on our owm server
# 1. ollama
# 2. huggingface
#
#
# git-->github(where we can host our code code is available in the repos)
# docker-->dockerhub(where we can keep our app in the form of images here is also we have a repo)
# huggingface-->huggingfacehub(over the huggingface hub you will have repo inside that repo model or dataset will be available)
# ollama-->ollama hub(here also we have severl model which we can download)
#
# github--> code-->download(in your local system)
# dockerhub-->pull the image(in your local system)
# huggingface hub-->model, dataset (in local system)
# ollama hub or modelhub --> model (in your local system)
#
# now lets suppose if you dont want take this overhead of configuring the model on your own server in that case
# you can use managed cloud platform
# here also you will have to be generate the API key
# this api key is going to cloud spcific api key
# 1. awzbedrock
# 2. azure AI cloud foundry
# 3. google vertex AI
# 4. huggingface api enterprise version
#
# we can access via langchain itself
#
# server means your owns system

# %% [markdown]
# text to text
#
# text to image
#
# image to text
#
# text to audio
#
# audio to text
#
# 1. openai/claude -> PAID
#
# 2. groq -> it has free access of the model(we can use this for learning purpos) and PAID also
#
# 3. openrouter -> it also provide free accesss
#
# 4. huggingface api -> it provide free access
#
# 5. gemini api (google) -> couple of models are free with limitation and they have PAID version also
#
# 6. Ollama -> you can completly download the model in your local and you can access
#
# LLMs
#
# these LLMs we are going to use in our RAG app, Agentic app
#
# text to text
#
# text to image
#
# LEADERBOARD

# %%
import os
OPENAI_API_KEY = os.getenv ("OPENAI_API_KEY")  # This will return None if the environment variable is not set
if OPENAI_API_KEY:
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-5-nano")

# %%
message = llm.invoke("What is the capital of India?")

# %%
message

# %% [markdown]
# #### Claude via LangChain
# Use Anthropic/Claude with `ANTHROPIC_API_KEY` and LangChain.

# %%
import os
ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")
if ANTHROPIC_API_KEY:
    os.environ["ANTHROPIC_API_KEY"] = ANTHROPIC_API_KEY

from langchain_anthropic import ChatAnthropic

llm = ChatAnthropic(
    model="claude-haiku-4-5-20251001",
    temperature=0
)

# %% [markdown]
# # Text to Image

# %%
llm =ChatAnthropic(model = "claude-haiku-4-5-20251001")

# %%
kwargs = {"type": "image_generation", "quality": "low"}

# %%
llm_with_tools =llm.bind_tools([kwargs])

# %%
ai_message = llm_with_tools.invoke("Draw a picture of a cute fuzzy cat with an umbrella")

# %%
ai_message

# %%
import base64
from IPython.display import Image

# %%
image = next(
    item for item in ai_message.content_blocks if item["type"] == "image"
)

# %%
Image(base64.b64decode(image["base64"]), width=200)

# %% [markdown]
# # Image to Text
#
# #### Model from  OPENAI
#
# #### OCR(optical character recognition)
#
# ##### to fetch a data from the images
#
# #### it is cv based technique
#
# #### ealier we were performing it using the CNN based model
#
# #### Now we can perform OCR task using the Transformer based model(ViT)
#
# #### These models plays a very imp role in MMRAG Pipeline

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

# %% [markdown]
# ## using this base64 encode we can perform bindary encoding of our data(image, audio, video)
#
# ### system is percoessing the data in binary form
#
# #### image(collection of pixel) is a data
#
# #### image required encoding and we are converting image image into the binary format(base64)

# %%
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# %%
base64_image = encode_image("D:\GenAI\FullStack-GenAI\Class-16-17-16&17-May-2026-LLM-Acess-Via-APIs\dogs.png")

# %%
base64_image

# %%
from langchain_core.messages import HumanMessage

# %%
message = HumanMessage(
    content=[
        {"type": "text", "text": "What is in this image?"},
        {
            "type": "image_url",
            "image_url": {
                "url": f"data:image/png;base64,{base64_image}"
            },
        },
    ]
)

# %%
message = HumanMessage(
    content=[
        {"type": "text", "text": "What is in this image?"},
        {
            "type": "image_url",
            "image_url": {
                "url": "https://www.coolutils.com/blog/wp-content/uploads/2025/06/jpg.png"
            },
        },
    ]
)

# %%
response = llm.invoke([message])

# %%
print(response.content)

# %% [markdown]
# The image features a playful illustration of six cartoon-style dogs. Each dog has a distinct expression, often with happy faces and their tongues out. The dogs vary in breed and fur textures, adding a fun and whimsical touch to the overall composition. The background is a solid color that contrasts nicely with the colorful dogs.

# %% [markdown]
# The image appears to be a graphic that features a question, "What Is a JPG File?" along with an icon representing a JPG file. The icon likely includes imagery such as a document with a picture symbol and the letters "JPG" prominently displayed, all set against a colorful background.

# %% [markdown]
# scratch --> limitation

# %% [markdown]
# So far we have seen OpenAI which is paid one
# Anthropic is also paid
# you can purchase their credits
# config the api key
# and run it via langchain
# Now lets access some free models
# text to text models
# text to image models
# image to text models
# are also possible
# 1. GROQ --? free access
# 2. Openrouter --? free access
# 3. Google(gemini api) --> here we have limited access of limited models
# 4. Huggingface Inferencing API
#
# HuggingfaceHUB
# OllamaHUB

# %% [markdown]
# ## Groq
# ## Text to text: free

# %%
import os
GROQ_API_KEY = os.getenv ("GROQ_API_KEY")  # This will return None if the environment variable is not set
if GROQ_API_KEY:
    os.environ["GROQ_API_KEY"] = GROQ_API_KEY

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    model="qwen/qwen3-32b")

# %%
## this message which we are passsing it is only called prompt or input 
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Hindi. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]

# %%
ai_msg = llm.invoke(messages)

# %%
print(ai_msg.content)

# %% [markdown]
# #### Groq
#
# ### Image to text: free

# %%
llm = ChatGroq(
    model="meta-llama/llama-4-scout-17b-16e-instruct"
)

# %%
message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "Describe this image in detail."
        },
        {
            "type": "image_url",
            "image_url": {
                "url": "https://www.coolutils.com/blog/wp-content/uploads/2025/06/jpg.png"
            }
        }
    ]
)

# %%
response = llm.invoke([message])

# %%
response

# %%
print(response.content)

# %% [markdown]
#   ### Openrouter
#   #### text to text: free

# %%
from dotenv import load_dotenv
load_dotenv()  # reads .env and sets env vars

# import os
# print(os.getenv("OPENROUTER_API_KEY"))
import os
OPENROUTER_API_KEY = os.getenv ("OPENROUTER_API_KEY")  # This will return None if the environment variable is not set
if OPENROUTER_API_KEY:
    os.environ["OPENROUTER_API_KEY"] = OPENROUTER_API_KEY

# %% [markdown]
# #### via openrouter you can access the claude model
#
# #### but guys here we have limitation (in the free versio)
#
# #### the limitation is we can only access 2659 tokens in input/output
#
# #### free version having a limit till max_tokens=2659

# %%
from langchain_openrouter import ChatOpenRouter

# %%
llm = ChatOpenRouter(model="anthropic/claude-sonnet-4.5",max_tokens=2048)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant.",
    ),
    ("human", "can you talk about the climate change?."),
]

# %%
ai_msg = llm.invoke(messages)

# %%
print(ai_msg.content)

# %% [markdown]
# ### checkout all the models provided by openrouter over here : https://openrouter.ai/models?input_modalities=text,image
#
# ##### as a homework you can practice or experiment with the different different model from the openrouter

# %% [markdown]
# #### huggingface
#
# ### text to text: free

# %%
import os


HUGGINGFACEHUB_API_TOKEN = os.getenv ("HUGGINGFACEHUB_API_TOKEN")  # This will return None if the environment variable is not set
if HUGGINGFACEHUB_API_TOKEN:
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = HUGGINGFACEHUB_API_TOKEN
    
# from dotenv import dotenv_values

# print(dotenv_values(r"D:\GenAI\FullStack-GenAI\.env"))
from dotenv import load_dotenv

load_dotenv(r"D:\GenAI\FullStack-GenAI\.env", override=True)

import os
# print(os.getenv("HUGGINGFACEHUB_API_TOKEN"))

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    # repo_id="deepseek-ai/DeepSeek-V4-Pro",
    task="text-generation",
    max_new_tokens=512
)

# %%
from langchain_huggingface import ChatHuggingFace

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Prompt(Input message) ---->LLM----->output(output message or AI-Message)
#
# user_message
#
# or
#
# system_message
# user_message
#
# we have two way of defining ths system and user message
#
# 1. first simple tuple format(older way of passing message but still relevant)
#
# messages = [
#     ("system", "You are a helpful assistant that translates English to Hindi. Translate the user sentence.",),
#     ("human", "I love programming.")
#      ]
#
# 2. second using SystemMessage class and HumanMessage class(latest way of defining message)
# latest LangChain variant
# messages = [
#     SystemMessage(content="You're a helpful assistant"),
#     HumanMessage( content="What happens when an unstoppable force meets an immovable object?"),
# ]
#
# SystemMessage or system -->we are defining the permanent behviour of llm in current active session
# HumanMessage or human --> whatever human wanted to provide input it is that message

# %% [markdown]
# SystemMessage just to set the role or the behaviour of the LLM for the active session.

# %%
from langchain_core.messages import SystemMessage, HumanMessage
messages = [
    SystemMessage(content="You're a helpful assistant"),
    HumanMessage(content="What happens when an unstoppable force meets an immovable object?")
]

# %%
ai_msg = chat_model.invoke(messages)

# %%
print(ai_msg.content)
# Out:
# <think>
# Okay, the user is asking about the classic paradox of an unstoppable force meeting an immovable object. This is a fun one!
#
# First, I should acknowledge that it's a logical contradiction disguised as a physics question. The user might be genuinely curious, or they could just be playing with philosophical concepts. Either way, they seem intellectually playful.
#
# Hmm, I recall that in real physics, nothing is truly unstoppable or immovable—those are idealized concepts. Maybe I should start by pointing out the paradox itself before diving into how physics would handle similar scenarios.
#
# The user probably isn't looking for a dry textbook answer. I should make it engaging. Maybe add a touch of humor? Like comparing it to dividing by zero. And oh—I should mention how modern physics approaches "unstoppable" things (like light or black holes) versus "immovable" ones (like neutron stars).
#
# Wait, does the user want a definitive answer? There isn't one, but I can explore why the question breaks down. I'll structure it: paradox first, then real-world parallels, then scientific perspectives.
#
# ... And I should end by reframing the question as a thought experiment. That way, it stays fun but grounded. No need to overcomplicate it—they're likely here for the mental gymnastics, not a lecture.
# </think>
#
#
# The classic paradox of an **unstoppable force** meeting an **immovable object** has no real-world solution because both concepts are **logically incompatible** under the same set of physical laws. Here's a breakdown:
#
# ### 1. **The Paradox Explained**
# - An "unstoppable force" implies something that **cannot be resisted** (e.g., it must move anything it encounters).
# - An "immovable object" implies something that **cannot be moved** (e.g., it must resist any force applied to it).
# - If they exist simultaneously, they violate the **conservation of momentum** and **Newton’s laws of motion**, creating a contradiction.
#
# ### 2. **Scientific Perspective**
# - **Physics**: In reality, nothing is truly "unstoppable" or "immovable." Forces and objects interact via energy transfer, deformation, or conversion (e.g., kinetic energy → heat/sound).
#   - *Example*: A meteor (unstoppable force) hitting Earth (immovable object?) would result in catastrophic deformation, heat, and shockwaves — both are altered.
# - **Relativity**: At near-light speeds, mass increases infinitely, making acceleration impossible (nothing is "unstoppable"). Similarly, no object is perfectly rigid (quantum uncertainty ensures everything can be moved).
#
# ### 3. **Philosophical/Cultural Resolutions**
# - **Mutual Destruction**: Both cancel each other out (e.g., force stops, object moves slightly).
# - **Redefinition**: One property must yield. If the force *is* unstoppable, the object *must* move (and isn’t immovable). If the object *is* immovable, the force *must* stop (and isn’t unstoppable).
# - **Absurdity**: Like asking, "What happens when an unanswerable question meets an unsatisfiable answer?" — it highlights the limits of language/logic.
#
# ### 4. **Pop Culture & Fun Answers**
# - **Comic Books**: Superman (unstoppable) vs. Captain Atom (immovable) might end in a universe-shattering explosion.
# - **Humorous Take**: "They negotiate a truce and open a coffee shop together."
#
# ### Conclusion
# The paradox is a **thought experiment** exposing contradictions in absolute definitions. In reality, **interaction always occurs**: energy dissipates, objects deform, or one "wins" based on context. It reminds

# %% [markdown]
# ### as a homework you can experiment with the different models from the huggingface Text to Image, Image to text, Audio to text, text to Audio

# %% [markdown]
# ### gemini(google)
#
# ### text to text : free tier available
#
# Model: gemini-2.5-flash (free)
#
# Model: gemini-2.5-pro(free)
#
# Model: gemini-2.5-flash-lite(free)
#
# Model: gemini-2.5-flash-native-audio-preview(free)
#
# Model: gemini-2.5-flash-preview-tts(free)
#
# Model: gemini-embedding-2(free)
#
# Model: gemini-embedding-001(free)

# %%
import os
from dotenv import load_dotenv
load_dotenv()  # reads .env and sets env vars

GOOGLE_API_KEY = os.getenv ("GOOGLE_API_KEY")  # This will return None if the environment variable is not set
if GOOGLE_API_KEY:
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %% [markdown]
# ## Text to Text model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite"
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]

# %%
ai_msg = model.invoke(messages)

# %%
print(ai_msg.content)
# Out:
# J'adore programmer.

# %% [markdown]
# ### google gemini
#
# ## Image to text

# %%
import base64
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# 1. Image ko base64 me convert karo
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

base64_image = encode_image("D:\GenAI\FullStack-GenAI\Class-16-17-16&17-May-2026-LLM-Acess-Via-APIs\dogs.png")
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\G'
# <>:10: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\koush\AppData\Local\Temp\ipykernel_4392\2562494944.py:10: SyntaxWarning: invalid escape sequence '\G'
#   base64_image = encode_image("D:\GenAI\FullStack-GenAI\Class-16-17-16&17-May-2026-LLM-Acess-Via-APIs\dogs.png")

# %%
# 2. Gemini model initialize karo
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=GOOGLE_API_KEY
)

# %%
# 3. Text + image message banao
message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "Describe this image in detail."
        },
        {
            "type": "image_url",
            "image_url": f"data:image/png;base64,{base64_image}"
        }
    ]
)

# %%
# 4. Model invoke karo
response = llm.invoke([message])

# %%
print(response.content)
# Out:
# The image is a vibrant and whimsical cartoon illustration featuring six distinct dog characters, arranged in two rows of three, against a solid, muted blue-green background. Each dog exhibits a highly expressive and exaggerated facial expression, characteristic of animated styles, with most having their tongues playfully hanging out.
#
# Here's a detailed breakdown of each dog, moving from left to right, top to bottom:
#
# **Top Row:**
#
# 1.  **Top-Left Dog:** This dog has a shaggy, medium-length coat in shades of brown, tan, and white, giving it a scruffy, terrier-like appearance. Its large, floppy ears are dark brown. Its face is dominated by wide, white eyes with small black pupils, giving it a surprised or excited look. Its mouth is wide open, revealing a pink tongue hanging out and a hint of a lower tooth. The muzzle area is lighter tan, and its nose is a prominent dark black. A simple dark brown collar with a silver ring is visible around its neck.
#
# 2.  **Top-Middle Dog:** This dog has a more exaggerated, almost caricatured look. Its fur is a mix of golden-brown and darker brown, with a somewhat wiry texture. It has large, floppy, pointed ears that are a rich brown. Its long snout gives it a dachshund or terrier mix feel. The eyes are wide, white, and slightly crossed, with small black pupils, conveying a goofy or bewildered expression. Its mouth is stretched into a wide, lopsided grin, with a long, pink tongue hanging far out to the right side of its face. Its nose is large and dark black, and there are subtle wrinkles around its eyes and muzzle.
#
# 3.  **Top-Right Dog:** This dog has a fluffy, curly coat, predominantly orange-brown, suggesting a Cocker Spaniel or similar breed. Its very long, curly ears frame its face. It has a bright, cheerful, and enthusiastic expression, with wide, sparkling white eyes and small black pupils. Its mouth is open in a broad smile, revealing a light pink tongue and a couple of white teeth. The muzzle is a lighter cream color, and its nose is a distinctive light blue. A thin, tan collar is visible around its neck, and more of its body, including its front paws, is shown compared to the other dogs in the top row.
#
# **Bottom Row:**
#
# 4.  **Bottom-Left Dog:** This dog has a sleek, short coat with patches of tan, brown, and black. Its ears are medium-sized, floppy, and black. It has a very happy and energetic expression, with wide, round white eyes and small black pupils. Its mouth is open in a wide, joyful grin, showing a pink tongue hanging out and a few white teeth. Its nose is dark black, and it has small, expressive black eyebrows. A black collar with a silver buckle is visible around its neck.
#
# 5.  **Bottom-Middle Dog:** This dog has a very shaggy, long coat in shades of dark brown, tan, and white, particularly around its face and ears. Its long, floppy ears are dark brown. Its expression is one of extreme surprise or shock, with very wide, almost bug-eyed white eyes and small black pupils. Its mouth is open very wide, and a long, pink tongue hangs straight down. Its muzzle is very fluffy and light-colored, and its nose is dark black.
#
# 6.  **Bottom-Right Dog:** This dog has a wavy or curly coat with patches of black and white, reminiscent of a Springer Spaniel or Border Collie mix. Its large, floppy ears are dark black. It has a sweet, curious, and slightly innocent expression, with wide, round white eyes and small black pupils. Its head is tilted slightly. Its mouth is open in a gentle smile, with a pink tongue peeking out. Its muzzle is white and fluffy, and its nose is dark black.
#
# Overall, the image showcases a delightful array of canine personalities through exaggerated features and expressive poses, all rendered in a charming, cartoon style.

# %% [markdown]
# # Audio → Text

# %%
import base64
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# %%
def encode_audio(audio_path):
    with open(audio_path, "rb") as audio_file:
        return base64.b64encode(audio_file.read()).decode("utf-8")

# %%
base64_audio = encode_audio("D:\GenAI\FullStack-GenAI\Class-16-17-16&17-May-2026-LLM-Acess-Via-APIs\output.wav")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\koush\AppData\Local\Temp\ipykernel_4392\3162981315.py:1: SyntaxWarning: invalid escape sequence '\G'
#   base64_audio = encode_audio("D:\GenAI\FullStack-GenAI\Class-16-17-16&17-May-2026-LLM-Acess-Via-APIs\output.wav")

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=GOOGLE_API_KEY
)

# %%
message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "Transcribe this audio into English text."
        },
        {
            "type": "media",
            "mime_type": "audio/mp3",
            "data": base64_audio
        }
    ]
)

# %%
response = llm.invoke([message])

# %%
print(response.content)
# Out:
# Hello students. Today, we are learning multimodal AI and you are in Sunny Savita class, where he is teaching you multimodal AI.

# %% [markdown]
# Hello students. Today we are learning about multimodal AI, one of the most exciting areas in artificial intelligence, where models can understand and generate multiple types of data such as text, images, audio, and video, enabling powerful applications like image captioning, speech recognition, text-to-image generation, AI voice assistants, visual question answering, and intelligent agentic systems that can interact with the world in a much more human-like way.

# %% [markdown]
# ### Text → Audio

# %% [markdown]
# here we are going to convert text to audio via gemini model
# you can convert using the different other model also(like openai is also providing you some models)
# some model you will get from huggingface/openrouter...
#
# # audio to audio
# # Image to image
# # video to video
# # text to audio,video
#
# but for these kind of task you will not always get langchain wrapper
#
# ### if dont have langchain wrapper so we can directly use those model via API SDK
#
# so we can directly use openai sdk/ google gemini sdk/ openrouter sdk

# %%
from google import genai
from google.genai import types
import wave

# %%
client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash-preview-tts", #freely accessible model for text to speech conversion
    contents="Mangsho chara ami mod khai nah",
    config=types.GenerateContentConfig(
        response_modalities=["AUDIO"],
        speech_config=types.SpeechConfig(
            voice_config=types.VoiceConfig(
                prebuilt_voice_config=types.PrebuiltVoiceConfig(
                    voice_name="Kore"
                )
            )
        )
    )
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[199], line 1
# ----> 1 response = client.models.generate_content(
#       2     model="gemini-2.5-flash-preview-tts", #freely accessible model for text to speech conversion
#       3     contents="Mangsho chara ami mod khai nah",
#       4     config=types.GenerateContentConfig(
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\google\genai\models.py:6526, in Models.generate_content(self, model, contents, config)
#    6522   parsed_config_to_call = _extra_utils.get_usage_header(
#    6523       parsed_config_to_call
#    6524   )
#    6525 i += 1
# -> 6526 response = self._generate_content(
#    6527     model=model, contents=contents, config=parsed_config_to_call
#    6528 )
#    6530 if not function_map:
#    6531   break
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\google\genai\models.py:4954, in Models._generate_content(self, model, contents, config)
#    4951 request_dict = _common.convert_to_dict(request_dict)
#    4952 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4954 response = self._api_client.request(
#    4955     'post', path, request_dict, http_options
#    4956 )
#    4958 if config is not None and getattr(
#    4959     config, 'should_return_http_response', None
#    4960 ):
#    4961   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\google\genai\_api_client.py:1618, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1608 def request(
#    1609     self,
#    1610     http_method: str,
#    (...)   1613     http_options: Optional[HttpOptionsOrDict] = None,
#    1614 ) -> SdkHttpResponse:
#    1615   http_request = self._build_request(
#    1616       http_method, path, request_dict, http_options
#    1617   )
# -> 1618   response = self._request(http_request, http_options, stream=False)
#    1619   response_body = (
#    1620       response.response_stream[0] if response.response_stream else ''
#    1621   )
#    1622   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\google\genai\_api_client.py:1411, in BaseApiClient._request(self, http_request, http_options, stream)
#    1408     retry = tenacity.Retrying(**retry_kwargs)
#    1409     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1411 return self._retry(self._request_once, http_request, stream)
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\google\genai\_api_client.py:1388, in BaseApiClient._request_once(self, http_request, stream)
#    1380   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1381       method=http_request.method,
#    1382       url=http_request.url,
#    (...)   1385       timeout=http_request.timeout,
#    1386   )
#    1387   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1388 errors.APIError.raise_for_response(response)
#    1389 return HttpResponse(
#    1390     response.headers, response if stream else [response.text]
#    1391 )
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File d:\GenAI\FullStack-GenAI\.venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     170 """Raises an appropriate APIError subclass based on the status code.
#     171
#     172 Args:
#    (...)    181   APIError: For other error status codes.
#     182 """
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#     186   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 10, model: gemini-2.5-flash-tts\nPlease retry in 50.495388826s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-tts'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '50s'}]}}

# %%
audio_data = response.candidates[0].content.parts[0].inline_data.data

with wave.open("output.wav", "wb") as wf:
    wf.setnchannels(1)
    wf.setsampwidth(2)
    wf.setframerate(24000)
    wf.writeframes(audio_data)

print("Audio saved as output.wav")
# Out:
# Audio saved as output.wav

# %% [markdown]
# ###

# %% [markdown]
# ## Ollama

# %% [markdown]
# ollama --version
# ollama help
#
# ollama serve
#
# ollama pull llama3.1
#
# ollama run llama3.1
#
# ollama list
#
# ollama ps
#
# ollama stop llama3.1
#
# ollama show llama3.1
#
# ollama show llama3.1 --modelfile
#
# ollama rm llama3.1

# %% [markdown]
# Ollama
# 1. download the model in our local
# <here it is going to be download over the local server>
#
# 2. we can directly access the model using Ollama cloud(Ollama already hosted the model)
# if we are accessing the model via Ollama cloud so we can only access limited model(free version)
# if we have a paid version of Ollama them we can access different other models also

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

# %%
# 1. Create local Ollama LLM
llm = ChatOllama(
    model="llama3.2:1b",
    temperature=0
)

# %%
# 1. Create local Ollama LLM
llm2 = ChatOllama(
    model="nemotron-3-super:cloud",
    temperature=0
)

# %%
# 2. Create messages
messages = [
    SystemMessage(content="You are a helpful AI assistant."),
    HumanMessage(content="Explain RAG in simple words in AI")
]

# %%
# 3. Invoke model
response = llm.invoke(messages)

# %%
response2 = llm2.invoke(messages)

# %%
print(response2.content)
# Out:
# Imagine you're asking a super-smart friend a question, but you know they sometimes **make up answers** when they're not sure (like confidently stating a false fact) or **don’t know recent news** (because their last update was years ago).
#
# **RAG (Retrieval-Augmented Generation) fixes this by giving your friend a "cheat sheet" *right before* they answer.** Here’s how it works in simple terms:
#
# 1. **You ask a question** (e.g., "What are the latest symptoms of the new flu strain?").
# 2. **Instead of relying only on what your friend already knows**, RAG **quickly searches a trusted, up-to-date source** (like a medical database or recent news articles).
# 3. **It pulls out the most relevant bits** from that source (e.g., a paragraph from yesterday’s CDC report).
# 4. **Your friend reads those bits** *while* forming their answer — so they’re answering **based on real, current facts**, not just memory or guesswork.
# 5. **They give you an answer** (and can even show you *where* the info came from, like citing the CDC report).
#
# ### Why is this useful?
# - ❌ **Without RAG**: Your friend might hallucinate ("I think the new flu causes purple spots!") or give outdated info ("Last year’s strain had fever...").
# - ✅ **With RAG**: They ground their answer in **real, verifiable data** — making it **more accurate, up-to-date, and trustworthy**.
#
# ### Simple Analogy:
# > Think of a regular AI as a student taking a closed-book exam (only using what they memorized).
# > **RAG is like giving that student an open-book exam** — but the book is *only* the pages relevant to the question, handed to them *right before* they start writing.
#
# ### Key Benefits:
# - **Reduces hallucinations** (AI sticks to facts from the source).
# - **Keeps knowledge current** (no need to retrain the AI for every new update).
# - **Lets you see sources** (so you can verify the answer yourself).
# - **Works with private data** (e.g., your company’s internal docs — without retraining the AI on them).
#
# In short: **RAG makes AI smarter by letting it "look things up" in real time — just like you or I would when we don’t know something.** It’s not magic; it’s giving the AI better homework help before it answers. 📚✨
#
# *Note: RAG doesn’t eliminate all errors (garbage in = garbage out), but it’s a huge step toward reliable, useful AI.*

# %%
# 4. Print output
print(response.content)
# Out:
# RAG is an acronym that stands for "Recall, Accuracy, and Generalization". In the context of artificial intelligence (AI), it refers to three key aspects of model performance.
#
# **Recall**: This measures how well a model can identify and detect instances where its predictions are correct. Think of it like finding all the birds in a forest when you're looking for them.
#
# **Accuracy**: This is a measure of how close a model's predictions are to the actual outcomes. It's like counting the number of birds that are actually found, compared to the total number of birds in the forest.
#
# **Generalization**: This refers to a model's ability to make accurate predictions on new, unseen data. It's like being able to find all the birds in a different forest, without knowing where they live initially.
#
# In simple terms, RAG is a way to evaluate how well an AI model performs across different scenarios and datasets. A good RAG score indicates that the model is reliable, accurate, and generalizable.

# %%
# !ollama pull bakllava

# %%
import base64
from pathlib import Path

from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage

def encode_image(image_path: str) -> str:
    image_bytes = Path(image_path).read_bytes()
    return base64.b64encode(image_bytes).decode("utf-8")

image_b64 = encode_image("image.jpg")

llm = ChatOllama(
    model="bakllava",
    temperature=0
)

message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "Describe this image in detail."
        },
        {
            "type": "image_url",
            "image_url": f"data:image/jpeg;base64,{image_b64}"
        }
    ]
)

response = llm.invoke([message])

print(response.content)

# %% [markdown]
# OpenAI
# Claude
# Gemini google
# Groq
# Openrouter
# Huggingface
#
# input   output
# Text -> Text
# Text -> Image
# Image -> Text
# Image -> Image(not required)
# Text-> Audio
# Audio -> Text
# Audio -> Audio(not required)
# text -> video
# video -> text
#
# you have to prepare a new notebook
# where use a different model(which i have not use in the live class) related to different modality
# and then generate a output
# once you are successed in the notebook
#
# create a webapp which is taking a input in every modality(text, image, audio, video)
# and generate a output accordingly
